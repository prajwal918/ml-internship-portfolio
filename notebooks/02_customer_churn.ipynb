# %% [markdown]
# # Customer Churn Prediction
#
# Notebook entry point for churn data checks, training, and evaluation.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from ml_portfolio.projects import churn

df, source = churn.dataset()
source, df.head()

# %%
result = churn.train_model()
result.metrics
