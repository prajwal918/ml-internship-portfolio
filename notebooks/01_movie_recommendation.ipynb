# %% [markdown]
# # Movie Recommendation System
#
# Notebook entry point for EDA, training, and evaluation.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from ml_portfolio.projects import movie

result = movie.train_model()
result.metrics

# %%
movie.recommend_for_user(1, top_n=10)
