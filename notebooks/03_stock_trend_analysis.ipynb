# %% [markdown]
# # Stock Market Trend Analysis
#
# Notebook entry point for OHLCV indicators, trend modeling, and backtest metrics.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from ml_portfolio.projects import stock

df = stock.sample_data()
df.head()

# %%
result = stock.train_model()
result.metrics
