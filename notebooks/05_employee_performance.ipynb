# %% [markdown]
# # Employee Performance Prediction
#
# Notebook entry point for HR analytics modeling and fairness checks.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from ml_portfolio.projects import employee

df, source = employee.dataset()
source, df.head()

# %%
result = employee.train_model()
result.metrics
