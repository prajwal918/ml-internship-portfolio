# %% [markdown]
# # Fake News Detection System
#
# Notebook entry point for text classification and evaluation.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from ml_portfolio.projects import fake_news

df, source = fake_news.dataset()
source, df.head()

# %%
result = fake_news.train_model()
result.metrics
